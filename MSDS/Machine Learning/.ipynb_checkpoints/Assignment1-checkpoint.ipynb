# %% [markdown]
# # Question 1

# %% [markdown]
# # Reading Training data

# %%
training_data=open("pp1data/pp1data/training_data.txt","r").read().split()

# %%
N=[640000,160000,40000,10000,5000]

# %%
file=[training_data,training_data[:N[1]],training_data[:N[2]],training_data[:N[3]],training_data[:N[4]]]

# %% [markdown]
# # Calculating Frequency

# %%
def frequency(data):
    freq={}
    for i in data:
        if i in freq.keys():
            freq[i]+=1
        else:
            freq[i]=1
    return freq

# %%
freq=[]
for i in file:
    freq.append(frequency(i))

# %% [markdown]
# # Calculating MLE models

# %%
def max_L(freq,N):
    mle={}
    for w in freq.keys():
        mle[w]=freq[w]/N
    return mle

# %%
mle=[]
for i in range(len(N)):
    temp=max_L(freq[i],N[i])
    mle.append(temp)

# %% [markdown]
# # Calculating MAP models

# %%
def max_a_p(freq,N):
    ma={}
    for w in freq.keys():
        ma[w]=(freq[w]+2-1)/(N+20000-10000)
    return ma

# %%
ma=[]
for i in range(len(N)):
    temp=max_a_p(freq[i],N[i])
    ma.append(temp)

# %% [markdown]
# # Calculating Predictive Distributions Models

# %%
def pred_dist(freq,N):
    pd={}
    for w in freq.keys():
        pd[w]=(freq[w]+2)/(N+20000)
    return pd

# %%
pd=[]
for i in range(len(N)):
    temp=pred_dist(freq[i],N[i])
    pd.append(temp)

# %% [markdown]
# # Calculating Perplexity

# %%
import math
import numpy as np

# %%
def perp(model,data):
    p=0
    for i in data:
        p+=np.log(model[i])
    perp=math.exp(-p/len(data))
    return perp

# %%
print("The perplexity on train set of MLE model is")
for i in range(len(N)):
    print("size: ",N[i]," Perplexity is ",perp(mle[i],file[i]))
# Out:
# The perplexity on train set of MLE model is
# size:  640000  Perplexity is  8506.43367662384
# size:  160000  Perplexity is  8292.385691215124
# size:  40000  Perplexity is  7478.035656314462
# size:  10000  Perplexity is  5005.389219343304
# size:  5000  Perplexity is  3388.2567752667333

# %%
print("The perplexity on train set of MAP model is")
for i in range(len(N)):
    print("size: ",N[i]," Perplexity is ",perp(ma[i],file[i]))
# Out:
# The perplexity on train set of MAP model is
# size:  640000  Perplexity is  8506.96513236839
# size:  160000  Perplexity is  8303.124332848962
# size:  40000  Perplexity is  7669.433287645091
# size:  10000  Perplexity is  6453.994771744834
# size:  5000  Perplexity is  5915.104263875246

# %%
print("The perplexity on train set of Predicitive Distribution model is")
for i in range(len(N)):
    print("size: ",N[i]," Perplexity is ",perp(pd[i],file[i]))
# Out:
# The perplexity on train set of Predicitive Distribution model is
# size:  640000  Perplexity is  8508.427803625034
# size:  160000  Perplexity is  8324.246394665119
# size:  40000  Perplexity is  7866.496544080013
# size:  10000  Perplexity is  7230.294305050776
# size:  5000  Perplexity is  7014.415012644821

# %% [markdown]
# # Reading Test data

# %%
test_data = open("pp1data/pp1data/test_data.txt", "r").read().split()

# %% [markdown]
# # Calculating Test Data Frequency

# %%
freq_test={}
for i in test_data:
    if i in freq_test:
        freq_test[i]=freq_test[i]+1
    else:
        freq_test[i]=1
print(freq_test)
# Out:
 88, 'Ruben': 103, 'schools': 42, 'noted': 59, 'rebounded': 76, 'Quite': 88, '7224': 79, '22792': 34, 'reserve': 62, 'stays': 107, 'hands': 30, 'cora': 158, 'struggled': 112, 'loathe': 81, 'purchase': 94, '23256': 50, 'Orsulak': 33, 'caught': 35, 'stands': 63, 'stunned': 12, 'tried': 43, 'tion': 42, 'ass': 74, 'felt': 63, 'Burkett': 143, 'Rex': 63, 'n09': 48, 'cs': 38, 'Sox': 53, 'ridiculously': 167, 'Howabout': 187, 'st1rp': 45, 'floating': 128, '24114': 33, 'Moeller': 28, 'kid': 95, 'Adjusted': 38, 'Wing': 95, '073051': 80, 'mystique': 51, 'Br': 92, 'edit': 92, 'forum': 37, 'fall': 118, 'Wood': 63, 'lot': 72, 'Boucher': 88, 'IBL': 63, 'spectacular': 60, 'erics': 65, '161730': 45, 'MIND': 65, 'neck': 147, 'mcmath': 133, 'Due': 109, 'State': 112, '316': 92, 'guffaws': 106, '8Iq': 23, 'laker': 65, 'revitalize': 59, '510': 55, '5155': 49, '80357': 69, 'dick': 31, '064154': 23, 'irrelevant': 87, 'Dunno': 105, 'Ethan': 15, 'ect': 144, 'Oriole': 172, 'pronunciation': 11, '13382': 81, '154311RVESTERM': 65, 'Enough': 95, '28099': 58, 'weighing': 82, 'Using': 61, '175302': 68, 'reentering': 55, 'decimation': 173, 'begin ...

# %% [markdown]
# # Testing the models

# %% [markdown]
# # MLE predictions

# %%
def test_max_L(test_data,mle,N):
    mle_prediction={}
    for w in test_data.keys():
        if w in mle.keys():
            mle_prediction[w]=mle[w]
        else:
            mle_prediction[w]=0/N
    return mle_prediction

# %%
test_mle=[]
for i in range(len(N)):
    temp=test_max_L(freq_test,mle[i],N[i])
    test_mle.append(temp)

# %% [markdown]
# # MAP Predictions

# %%
def test_max_a_p(test_data,ma,N):
    ma_prediction={}
    for w in test_data.keys():
        if w in ma.keys():
            ma_prediction[w]=ma[w]
        else:
            ma_prediction[w]=(0+2-1)/(N+20000-10000)
    return ma_prediction

# %%
test_ma=[]
for i in range(len(N)):
    temp=test_max_a_p(freq_test,ma[i],N[i])
    test_ma.append(temp)
print(test_ma[0])
# Out:
# {'pictures': 7.846153846153847e-05, 'wacky': 0.00015846153846153847, 'PSILink': 0.0001276923076923077, 'shades': 7.692307692307693e-05, 'Phill': 0.00015692307692307693, 'maneuver': 5.2307692307692306e-05, 'tying': 8.153846153846153e-05, '97330': 0.00014307692307692307, 'Finally': 0.00011076923076923077, 'Given': 0.0002323076923076923, 'UpdateDIR': 8.307692307692307e-05, 'ethical': 0.00015846153846153847, 'Rhyne': 0.00012307692307692307, 'mot': 6.76923076923077e-05, 'Step': 8.307692307692307e-05, 'exciting': 0.00012, '17845': 0.00018, 'salty': 8.307692307692307e-05, 'suddenly': 8e-05, 'concession': 0.0001476923076923077, 'humble': 0.00014, 'hype': 5.2307692307692306e-05, 'lafcol': 0.00014923076923076923, 'psl': 9.692307692307692e-05, '1973': 0.00014, 'Heaton': 0.00026, 'davewood': 0.00011538461538461538, 'conditioning': 0.00018615384615384615, 'Grateful': 5.538461538461539e-05, '12231': 5.846153846153846e-05, 'kepler': 7.076923076923076e-05, 'largely': 5.076923076923077e-05, '18': 0.00018923076923076923
            pd_prediction[w]=pd[w]
        else:
            pd_prediction[w]=(0+2)/(N+20000)
    return pd_prediction

# %%
test_pd=[]
for i in range(len(N)):
    temp=test_pred_dist(freq_test,pd[i],N[i])
    test_pd.append(temp)
print(test_pd[0])
# Out:
# {'pictures': 7.878787878787879e-05, 'wacky': 0.00015757575757575757, 'PSILink': 0.00012727272727272728, 'shades': 7.727272727272727e-05, 'Phill': 0.00015606060606060607, 'maneuver': 5.303030303030303e-05, 'tying': 8.181818181818182e-05, '97330': 0.00014242424242424243, 'Finally': 0.00011060606060606061, 'Given': 0.0002303030303030303, 'UpdateDIR': 8.333333333333333e-05, 'ethical': 0.00015757575757575757, 'Rhyne': 0.00012272727272727272, 'mot': 6.818181818181818e-05, 'Step': 8.333333333333333e-05, 'exciting': 0.0001196969696969697, '17845': 0.00017878787878787878, 'salty': 8.333333333333333e-05, 'suddenly': 8.03030303030303e-05, 'concession': 0.00014696969696969696, 'humble': 0.0001393939393939394, 'hype': 5.303030303030303e-05, 'lafcol': 0.00014848484848484849, 'psl': 9.696969696969698e-05, '1973': 0.0001393939393939394, 'Heaton': 0.00025757575757575756, 'davewood': 0.00011515151515151515, 'conditioning': 0.00018484848484848484, 'Grateful': 5.606060606060606e-05, '12231': 5.909090909090909e-05, 'kepler': 7.121212121212121e-05, 'largely': 5.151515151515152e-05, '18': 0.00018787878787878787, 'offset': 0.00015, 'logical': 0.0003227272727272727, '515': 0.00027272727272727274, '1qmk3j': 6.818181818181818e-05, 'placed': 0.00016666666666666666, 'convincing': 0.00011818181818181818, 'Watson': 0.00010151515151515152, 'wonder': 9.242424242424242e-05, 'progress': 9.242424242424242e-05, '369': 0.0002484848484848485, 'salvaging': 9.848484848484849e-05, 'retire': 7.727272727272727e-05, 'cole': 0.00015454545454545454, 'Phills': 9.393939393939393e-05, 'Dykstra': 8.333333333333333e-05, 'condiments': 0.0001696969696969697, 'Brookens': 6.515151515151516e-05, 'parks': 0.00013333333333333334, 'Great': 0.00016363636363636363, 'LEAD': 8.787878787878787e-05, 'SORRY': 0.000253030303030303, 'blowouts': 9.242424242424242e-05, 'confuse': 8.333333333333333e-05, '155315': 0.00014696969696969696, 'outliers': 0.00015454545454545454, 'we': 0.00016515151515151516, 'Y': 0.00011212121212121212, 'renegade': 9.393939393939393e-05, 'Hassey': 5.4545454545454546e-05, '750': 0.00017272727272727272, 'Commonwealth': 5.151515151515152e-05, 'heard': 9.09090909090909e-05, 'veteran': 0.00014242424242424243, 'guvax': 0.00015151515151515152, 'nieves': 0.00010303030303030303, 'flattering': 0.0001606060606060606, '121': 0.00018484848484848484, 'Hurst': 0.00012424242424242425, 'blasphemy': 0.00014545454545454546, 'Back': 0.0001318181818181818, 'Knight': 0.00010909090909090909, 'contend': 0.00016363636363636363, 'Matt': 0.00011363636363636364, 'hero': 0.00015454545454545454, 'cray': 0.00013333333333333334, 'Psm82B2w164w': 9.848484848484849e-05, 'defending': 0.00015151515151515152, 'corp': 9.545454545454546e-05, 'By': 0.00036515151515151517, 'closer': 0.00010151515151515152, 'intense': 7.575757575757576e-05, 'eechen': 0.0002621212121212121, 'Fair': 0.00025909090909090907, 'C56zrA': 7.575757575757576e-05, 'Princeto': 0.00017272727272727272, 'wuphys': 7.272727272727273e-05, 'Friday': 0.00014242424242424243, '1qn5vq': 0.0001681818181818182, 'times': 0.0001803030303030303, 'Jerald': 7.727272727272727e-05, '150026': 9.09090909090909e-05, 'dry': 0.00011212121212121212, 'G7': 0.0002606060606060606, 'Pose': 7.121212121212121e-05, 'C5J68F': 0.00015, 'hung': 9.545454545454546e-05, '55': 0.0001303030303030303, 'share': 0.00014696969696969696, 'case': 0.00010909090909090909, 'Newsreader': 4.848484848484849e-05, 'FLORIDA': 0.0001196969696969697, 'bruchner': 0.0002287878787878788, 'Sepinwall': 0.0001318181818181818, '161414RVESTERM': 4.393939393939394e-05, 'Sonny': 6.212121212121213e-05, 'lose': 9.848484848484849e-05, 'Wilson': 0.00013484848484848484, 'Moines': 0.00011818181818181818, 'nice': 0.00010454545454545455, 'prohibited': 0.00010454545454545455, 'whitaker': 0.0001, 'Generally': 5e-05, '6457': 6.515151515151516e-05, 'Unfortunately': 7.878787878787879e-05, 'loss': 8.484848484848485e-05, 'Deep': 0.00010909090909090909, 'Give': 0.00023484848484848486, 'Brown': 0.0001696969696969697, 'tv': 5 ...

# %% [markdown]
# # Perplexities of all predictions

# %%
print("The perplexity on train set of MLE model is")
for i in range(len(N)):
    print("size: ",N[i]," Perplexity is ",perp(test_mle[i],test_data))
# Out:
# The perplexity on train set of MLE model is
# size:  640000  Perplexity is  8657.623041731129
# C:\Users\aarya\AppData\Local\Temp\ipykernel_19060\3930523767.py:4: RuntimeWarning: divide by zero encountered in log
#   p+=np.log(model[i])
# size:  160000  Perplexity is  inf
# size:  40000  Perplexity is  inf
# size:  10000  Perplexity is  inf
# size:  5000  Perplexity is  inf

# %%
print("The perplexity on train set of MAP model is")
for i in range(len(N)):
    print("size: ",N[i]," Perplexity is ",perp(test_ma[i],test_data))
# Out:
# The perplexity on train set of MAP model is
# size:  640000  Perplexity is  8654.590090965366
# size:  160000  Perplexity is  8839.546029448937
# size:  40000  Perplexity is  9380.752312326787
# size:  10000  Perplexity is  9992.362371992125
# size:  5000  Perplexity is  10098.36492411617

# %%
print("The perplexity on train set of Predictive Distribution model is")
for i in range(len(N)):
    print("size: ",N[i]," Perplexity is ",perp(test_pd[i],test_data))
# Out:
# The perplexity on train set of Predictive Distribution model is
# size:  640000  Perplexity is  8652.803792634657
# size:  160000  Perplexity is  8817.904839672385
# size:  40000  Perplexity is  9224.511912933269
# size:  10000  Perplexity is  9668.062580182157
# size:  5000  Perplexity is  9814.024919445475

# %% [markdown]
# # Plotting the Graphs

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
x=N
y1=[]
for i in range(len(N)):
    y1.append(perp(mle[i],file[i]))
y2=[]
for i in range(len(N)):
    y2.append(perp(ma[i],file[i]))
y3=[]
for i in range(len(N)):
    y3.append(perp(pd[i],file[i]))
y4=[]
y4.append(perp(test_mle[0],test_data))
for i in range(4):
    y4.append(12000)
y5=[]
for i in range(len(N)):
    y5.append(perp(test_ma[i],test_data))
y6=[]
for i in range(len(N)):
    y6.append(perp(test_pd[i],test_data))

# %%
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.plot(x, y5)
plt.plot(x, y6)
plt.legend(["MLE-train", "MAP-train", "PD-train", "MLE-test", "MAP-test", "PD-test"])

plt.show()
