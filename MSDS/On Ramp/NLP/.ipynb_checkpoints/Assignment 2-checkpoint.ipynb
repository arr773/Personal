# %%
# # li=["Claudius", "King of Denmark.",
# # "Marcellus", "Officer.",
# # "Osric", "courtier.",
# # ["Hamlet","son to the former","and nephew to the present king."],
# # ["Polonius", "Lord Chamberlain."],
# # ["Horatio", "friend to Hamlet."],
# # ["Laertes"," son to Polonius."],
# # ["Voltemand"," courtier."],
# # ["Osric", "courtier."]]
# li="Claudius, King of Denmark. Marcellus, Officer. Osric, courtier. Hamlet, son to the former, and nephew to the present king. Polonius, Lord Chamberlain. Horatio, friend to Hamlet. Laertes, son to Polonius. Voltemand, courtier. Osric, courtier."
# with open("data.txt",'w') as file:
#     file.writelines(li)

# %%
# with open("data.txt",'r') as file:
#     data=file.read()
# data

# %%
with open("eBook_datafile.txt",'rt',encoding="utf8") as file:
    data=file.read()

# %%
#no of words
print(len(data.split()))
#no of unique words
print(len(set(data.split())))
# Out:
# 22249
# 4004

# %%
import nltk
from nltk.text import Text
from nltk.tokenize import word_tokenize
from nltk.book import *
t=word_tokenize(data)
words=Text(t)
words.concordance("years")
# Out:
# Displaying 25 of 29 matches:
# epers . We shall be sentenced to ten years in the Palace of Corrective Detentio
# ir names upon it . We are twenty-one years old . We are six feet tall , and thi
# on the marble , which come from more years than men could count . And these wor
# rth , else we are sentenced to three years in the Palace of Corrective Detentio
# nts where we lived till we were five years old , together with all the children
# ellar most often . When we were five years old , we were sent to the Home of th
# re there are ten wards , for our ten years of learning . Men must learn till th
# ity 7-2521 , were not happy in those years in the Home of the Students . It was
# bodies. ” We knew this well , in the years of our childhood , but our curse bro
# one , which was found only a hundred years ago , of how to make candles from wa
# ries . And there they study for many years , so that they may become candidates
# ...

# %%
li=[]
for i in set(words):
    if i.startswith("b"):
        li.append(i)
li.sort()
print(li)
# Out:
# ['b', 'back', 'backed', 'bag', 'bandage', 'banner', 'banners', 'bar', 'bare', 'barren', 'barrier', 'bars', 'base', 'based', 'battle', 'be', 'be.', 'beacon', 'beam', 'bear', 'bearers', 'beasts', 'beat', 'beating', 'beautiful', 'beauty', 'became', 'because', 'become', 'becomes', 'bed', 'beds', 'been', 'befell', 'before', 'beg', 'beggar', 'begging', 'begin', 'beginning', 'begun', 'behind', 'behold', 'being', 'believe', 'believed', 'bell', 'belong', 'belongs', 'below', 'beneath', 'bent', 'beside', 'besides', 'best', 'betray', 'betrayed', 'betraying', 'better', 'between', 'beyond', 'bid', 'bidding', 'big', 'binary', 'bird', 'birds', 'birth', 'birthday', 'bit', 'bitterness', 'black', 'blacker', 'blade', 'blankets', 'bleed', 'bless', 'blessed', 'blessing', 'blew', 'blind', 'blinding', 'blindly', 'blindness', 'blood', 'blow', 'blown', 'blows', 'blue', 'boast', 'bodies', 'bodies.', 'body', 'body.', 'bond', 'bones', 'book', 'books', 'boon', 'bore', 'bored', 'born', 'botched', 'both', 'bottles'
# ...

# %%
for i in (words):
    if i == 'transgression':
        word = data.replace(str(i), str('crime'))
        f = open('eBook_datafile.txt', 'w')
        f.write(word)
        f.close()
for i in (words):        
    if i =="Transgression":
        word = data.replace(str(i), str('crime'))
        f = open('eBook_datafile.txt', 'w')
        f.write(word)
        f.close()

# %%
with open("eBook_datafile.txt",'rt') as file:
    data=file.read()
t=word_tokenize(data)
words=Text(t)
words.concordance("transgression")
# Out:
# no matches

# %%
for i in set(words):
    if i.isupper():
        print(i)
# Out:
# 'AS-IS
# STRICT
# WILL
# OTHER
# NOT
# 1.F
# TWO
# INCLUDING
# FOR
# 1.E.6
# TRADEMARK
# ONLY
# FIVE
# RIGHT
# UTF-8
# AGREE
# UNDER
# DAMAGE
# _WE_
# 1.E.8
# GIVE
# 1.F.1
# TO
# 1.E.2
# YOU
# CONSEQUENTIAL
# ASCII
# LIABILITY
# LLC
# PART
# PLEASE
# PROJECT
# ACTUAL
# DISTRIBUTOR
# IF
# 1.C
# ARE
# FITNESS
# LICENSE
# ALL
# THOSE
# GUTENBERG
# INDIVISIBLE
# CONTENTS
# SEND
# AGREEMENT
# TEN
# FULL
# B.
# ANYTHING
# ANY
# PROVIDED
# PO
# 1.B
# I
# DIRECT
# IMPLIED
# THIS
# 1.E.5
# SUCH
# KIND
# WORK
# IRS
# EXCEPT
# 1.E
# USE
# BREACH
# TWELVE
# UT
# NEGLIGENCE
# AK
# FOUNDATION
# S.
# ELEVEN
# LIABLE
# 1.F.2
# 1.A
# PARAGRAPH
# 1.E.1
# OF
# POSSIBILITY
# REMEDIES
# PGLAF
# REFUND
# WITH
# I.
# EVEN
# EGO
# READ
# INDIRECT
# FOREVER.
# END
# ONE
# BUT
# PG
# 1.F.6
# START
# OR
# BE
# MEN
# THERE
# MERCHANTABILITY
# REPLACEMENT
# NINE
# THREE
# BEFORE
# HAVE
# IN
# 1.E.9
# THE
# INDEMNITY
# LIMITED
# DISTRIBUTE
# EIN
# AND
# PURPOSE
# DISCLAIMER
# FOUR
# A
# WARRANTY
# SIX
# DAMAGES
# ...

# %%
for i in set(words):
    if any(chr.isalpha() for chr in i) and any(chr.isdigit() for chr in i) or i.isdigit():
        print(i)
# Out:
# 1.F
# 1.E.6
# UTF-8
# 1250-0.zip
# 21
# 1.E.8
# 1.F.1
# 801
# 1.E.2
# 1250
# 1.C
# 30
# 750175
# 60
# 1.B
# 50
# 3
# 1.E.5
# 1.E
# //www.gutenberg.org/1/2/5/1250/
# 1.F.2
# 1.A
# 1.E.1
# 5
# 1250-0.txt
# 90
# 4
# 1.F.6
# 99775
# 501
# 2
# 1998
# 1.E.9
# 20
# 1500
# 1
# 1.E.3
# 84116
# 1.E.4
# 2001
# 1.D
# 1.F.4
# 1.F.3
# 1.E.7
# 2021
# 1.F.5
# 809

# %%
for i in set(words):
    if 'G' in i:
        print(i)
# Out:
# Gutenberg
# Gaea
# Great
# INCLUDING
# Golden
# RIGHT
# AGREE
# DAMAGE
# GIVE
# Give
# GUTENBERG
# General
# Gutenberg-tm
# AGREEMENT
# ANYTHING
# NEGLIGENCE
# PARAGRAPH
# PGLAF
# EGO
# PG
# Gregory
# GUTENBERG-tm
# DAMAGES
# Gutenberg-tm's
# GREAT
# EIGHT

# %%
for i in set(words):
    if 'sa' in i:
        print(i)
# Out:
# passages
# sages
# sands
# say.
# saints
# sand
# say
# thousand
# thousands
# said
# sank
# save
# same
# disaster
# savage
# saw
# sat
# saying
# sacrifice
# sanction
# Peasants
# sacred
# necessarily
# sadness
# sake
# sails
# impassable
# satisfaction
# says
# salute

# %%
for i in set(words):
    if len(i)>4:
        print(i)
# Out:
# sunlight
# seized
# kneel
# kneeling
# candle
# uncharted
# 'AS-IS
# equally
# sides
# fields
# prison
# track
# complying
# wildly
# parents
# individual
# Forest
# tongue
# stepping
# swayed
# throughout
# afraid
# duties
# created
# terror
# future
# STRICT
# assistance
# bleed
# worked
# along
# Clerks
# containing
# transition
# follows
# clean
# aside
# going
# palms
# defies
# license
# types
# interpreted
# carried
# OTHER
# quiet
# spine
# intellectual
# restrain
# limitation
# clung
# tunic
# bottom
# hanging
# transcribe
# protect
# haunts
# accepting
# Gutenberg
# Rather
# must.
# reaching
# mercy
# destroyed
# locations
# agent
# array
# hollow
# Replacement
# lunged
# shudder
# fangs
# Great
# effort
# Donations
# despair
# toiled
# touched
# backed
# eighteen
# froth
# require
# displaying
# Equality
# wanted
# causes
# bodies.
# ecstasy
# after
# wishes
# unspeakable
# Councils
# grown
# fought
# also.
# halting
# columns
# drink
# soon.
# error
# strokes
# Fairbanks
# ...

# %%
for i in set(text3):
    if i.isupper():
        print(i)
# Out:
# O
# G
# I
# LO
# A
# LORD

# %%
data.split()[-2:]
# Out:
# ['new', 'eBooks.']
